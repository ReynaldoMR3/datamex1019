# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
from sklearn.metrics import silhouette_score
from sklearn import cluster
kmeans=cluster.KMeans(n_clusters=8)
kmeans.fit(X)
y8_pred=kmeans.predict(X)
print ('K means 8 clusters: Silhouette_Score={}'.format(silhouette_score(X, y8_pred)))
# Out:
# K means 8 clusters: Silhouette_Score=0.5406824747857625

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=5)
kmeans.fit(X)
y5_pred=kmeans.predict(X)
print ('K means 5 clusters: Silhouette_Score={}'.format(silhouette_score(X, y5_pred)))
# Out:
# K means 5 clusters: Silhouette_Score=0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=3)
kmeans.fit(X)
y3_pred=kmeans.predict(X)
print ('K means 5 clusters: Silhouette_Score={}'.format(silhouette_score(X, y3_pred)))
# Out:
# K means 5 clusters: Silhouette_Score=0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
modelo=KMeans()
visual=KElbowVisualizer(modelo, k=(1,10))
visual.fit(X)
visual.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
aggmodel=cluster.AgglomerativeClustering()
visual=KElbowVisualizer(aggmodel, k=(1,10))
visual.fit(X)
visual.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
newdf = X.copy()

# %%
import seaborn as sns
single=cluster.AgglomerativeClustering(n_clusters=3)
single.fit(X)
y1_pred=single.labels_
newdf['labels']= y1_pred

# %%
sns.set(style="ticks")
sns.pairplot(newdf, hue="labels")
# Out:
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca=PCA(2).fit(newdf)
pca_x=pca.transform(newdf)

# %%
fig=plt.figure(figsize=(12,8))
ax = plt.subplot()
ax.scatter(pca_x[:,0], pca_x[:,1], c=newdf['labels']);

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE
fig, ax=plt.subplots(1, 4, figsize=(17,7))

for i, p in enumerate([3, 6, 12, 24]):
    tsne=TSNE(perplexity=p)
    x_emb=tsne.fit_transform(newdf)
    ax[i].scatter(x_emb[:,0], x_emb[:,1], c=y, cmap='Spectral')
    ax[i].set_title('Perplexity={}'.format(p))
    
plt.show();
